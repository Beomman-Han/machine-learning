# %%
## one-hot encoding practice with pandas
import pandas as pd

# %%
titanic_df = pd.read_csv('./data/titanic.csv', index_col=0)
titanic_df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
## transform 'Sex', 'Embarked' categorical data to numerical data
titanic_sex_embarked = titanic_df[['Sex', 'Embarked']]
titanic_sex_embarked
# Out:
#         Sex Embarked
# 0      male        S
# 1    female        C
# 2    female        S
# 3    female        S
# 4      male        S
# ..      ...      ...
# 886    male        S
# 887  female        S
# 888  female        S
# 889    male        C
# 890    male        Q
#
# [891 rows x 2 columns]

# %%
## one-hot encoding
one_hot_encoded_df = pd.get_dummies(titanic_sex_embarked)
one_hot_encoded_df.head()
# Out:
#    Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0           0         1           0           0           1
# 1           1         0           1           0           0
# 2           1         0           0           0           1
# 3           1         0           0           0           1
# 4           0         1           0           0           1

# %%
## one-hot encoding for specific columns from whole dataframe
one_hot_encoded_df = pd.get_dummies(data=titanic_df, columns=['Sex', 'Embarked'])
one_hot_encoded_df.head()
# Out:
#    Survived  Pclass                                               Name   Age  \
# 0         0       3                            Braund, Mr. Owen Harris  22.0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2         1       3                             Heikkinen, Miss. Laina  26.0
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4         0       3                           Allen, Mr. William Henry  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin  Sex_female  Sex_male  \
# 0      1      0         A/5 21171   7.2500   NaN           0         1
# 1      1      0          PC 17599  71.2833   C85           1         0
# 2      0      0  STON/O2. 3101282   7.9250   NaN           1         0
# 3      1      0            113803  53.1000  C123           1         0
# 4      0      0            373450   8.0500   NaN           0         1
#
#    Embarked_C  Embarked_Q  Embarked_S
# ...
