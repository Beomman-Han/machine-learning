# %%
import pandas as pd

# %%
df = pd.read_csv('data/enrolment_1.csv')
df
# Out:
#            id  year           course name
# 0     2777729     1               science
# 1     2777730     2               science
# 2     2777765     1                  arts
# 3     2777766     2                  arts
# 4     2777785     1                   mba
# ...       ...   ...                   ...
# 1995  2796805     3  computer application
# 1996  2796812     1               nursing
# 1997  2796813     2               nursing
# 1998  2796814     3               nursing
# 1999  2796815     4               nursing
#
# [2000 rows x 3 columns]

# %%
cond1 = (df['year'] == 1) & (df['course name'] == 'information technology')
cond1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
cond2 = (df['year'] == 4) & (df['course name'] == 'commerce')
cond2
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
df['status'] = 'allowed'
df.loc[(cond1 | cond2), 'status'] = 'not allowed'
df['status'].describe()
# Out:
# count        2000
# unique          2
# top       allowed
# freq         1990
# Name: status, dtype: object

# %%
course_count = df.loc[df['status'] == 'allowed', 'course name'].value_counts()

# %%
closed = course_count[course_count < 5]
closed.index
# Out:
# Index(['refactoring', 'mechanical related subjects',
#        'electros & communicationnic', 'database', 'bpt', 'engg. & tech.',
#        'information subjects', 'mechanical engg.', 'mech', 'civil engg',
#        ...
#        'physical edu.', 'humanities and social science (h', 'sciences',
#        'lib. & info sci', 'arts/science', 'biological sciences',
#        'aqua culture', 'pg.diploma', 'chemstry', 'full time'],
#       dtype='object', length=214)

# %%
for course in closed.index:
    df.loc[df['course name'] == course, 'status'] = 'not allowed'

# %%
df.head(30)
# Out:
#          id  year       course name       status
# 0   2777729     1           science      allowed
# 1   2777730     2           science      allowed
# 2   2777765     1              arts      allowed
# 3   2777766     2              arts      allowed
# 4   2777785     1               mba      allowed
# 5   2777786     2               mba      allowed
# 6   2777793     1     mba 2nd shift  not allowed
# 7   2777794     2     mba 2nd shift  not allowed
# 8   2777795     1     mca 2nd shift  not allowed
# 9   2777796     2     mca 2nd shift  not allowed
# 10  2777797     3     mca 2nd shift  not allowed
# 11  2777798     1              bjmc  not allowed
# 12  2777799     2              bjmc  not allowed
# 13  2777800     3              bjmc  not allowed
# 14  2777814     1           history      allowed
# 15  2777815     2           history      allowed
# 16  2777837     4         chemistry      allowed
# 17  2777858     4            botany      allowed
# ...
